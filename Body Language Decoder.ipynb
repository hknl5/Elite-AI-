# %% [markdown]
# # **Body-Language-Decoder**

# %% [markdown]
# # 0. Installing and Importing Dependencies

# %%
import mediapipe as mp #Importing mediapipe
import cv2 #Importing cv2
# Out:
# 2024-07-08 11:14:41.770916: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
mp_drawing = mp.solutions.drawing_utils # Drawing helpers
mp_holistic = mp.solutions.holistic # Mediapipe Solutions

# %% [markdown]
# # 1. Detections

# %%
#Getting Feed from Webcam, depending on your local PC, changing the numerical value in the VideoCapture command may be needed if it doesnt work
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    while cap.isOpened():
        ret, frame = cap.read()

        #Recoloring the Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        #Making Detections, all detections are being stored in the 'results' variable here.
        results = holistic.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        #1. Drawing face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                                  mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                  )

        #2. Right Hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                  )
        #3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                  )
        #4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                  )
        
        #Renders results to the screen
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows
# Out:
# I0000 00:00:1720427275.269539   11149 gl_context.cc:357] GL version: 2.1 (2.1 INTEL-22.5.11), renderer: Intel(R) Iris(TM) Plus Graphics OpenGL Engine
# W0000 00:00:1720427275.424068   22818 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720427275.449625   22816 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720427275.450922   22820 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720427275.451132   22818 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720427275.452224   22816 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720427275.461329   22816 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720427275.467577   22817 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720427275.476589   22821 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body Language Decoder.ipynb Cell 6 line 1
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#W5sZmlsZQ%3D%3D?line=10'>11</a> image.flags.writeable = False
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#W5sZmlsZQ%3D%3D?line=12'>13</a> #Making Detections, all detections are being stored in the 'results' variable here.
# ---> <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#W5sZmlsZQ%3D%3D?line=13'>14</a> results = holistic.process(image)
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#W5sZmlsZQ%3D%3D?line=15'>16</a> image.flags.writeable = True
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#W5sZmlsZQ%3D%3D?line=16'>17</a> image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mediapipe/python/solutions/holistic.py:160, in Holistic.process(self, image)
#     136 def process(self, image: np.ndarray) -> NamedTuple:
#     137   """Processes an RGB image and returns the pose landmarks, left and right hand landmarks, and face landmarks on the most prominent person detected.
#     138
#     139   Args:
#    (...)
#     157          "enable_segmentation" is set to true.
#     158   """
# --> 160   results = super().process(input_data={'image': image})
#     161   if results.pose_landmarks:  # pytype: disable=attribute-error
#     162     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mediapipe/python/solution_base.py:340, in SolutionBase.process(self, input_data)
#     334   else:
#     335     self._graph.add_packet_to_input_stream(
#     336         stream=stream_name,
#     337         packet=self._make_packet(input_stream_type,
#     338                                  data).at(self._simulated_timestamp))
# --> 340 self._graph.wait_until_idle()
#     341 # Create a NamedTuple object where the field names are mapping to the graph
#     342 # output stream names.
#     343 if self._output_stream_type_info is None:
#
# KeyboardInterrupt:

# %%
results.face_landmarks.landmark[0].visibility
# Out:
# 0.0

# %% [markdown]
# # 2. Capture Landmarks & Export to CSV

# %% [markdown]
# **Installing and Importing Dependencies**

# %%
import csv
import os
import numpy as np

# %%
# Established the num_coordinates variable to establish the number of coordinates we will have to go through

num_coordinates = len(results.pose_landmarks.landmark)+len(results.face_landmarks.landmark)
num_coordinates
# Out:
# 501

# %%
# Established the num_coordinates variable to establish the number of coordinates we will have to go through
landmarks = ['class']
# Loop through the range from 1 to num_coordinates
for val in range(1, num_coordinates+1):
    landmarks += ['x{}'.format(val), 'y{}'.format(val), 'z{}'.format(val), 'v{}'.format(val)]

# %%
landmarks
# Out:
# ['class',
#  'x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33',
#  'x34',
#  'y34',
#  'z34',
#  'v34',
#  'x35',
#  'y35',
#  'z35',
#  'v35',
#  'x36',
#  'y36',
#  'z36',
#  'v36',
#  'x37',
#  'y37',
#  'z37',
#  'v37',
#  'x38',
#  'y38',
#  'z38',
#  'v38',
#  'x39',
#  'y39',
#  'z39',
#  'v39',
#  'x40',
#  'y40',
#  'z40',
#  'v40',
#  'x41',
#  'y41',
#  'z41',
#  'v41',
#  'x42',
#  'y42',
#  'z42',
#  'v42',
#  'x43',
#  'y43',
#  'z43',
#  'v43',
#  'x44',
#  'y44',
#  'z44',
#  'v44',
#  'x45',
#  'y45',
#  'z45',
#  'v45',
#  'x46',
#  'y46',
#  'z46',
#  'v46',
#  'x47',
#  'y47',
#  'z47',
#  'v47',
#  'x48',
#  'y48',
#  'z48',
#  'v48',
#  'x49',
#  'y49',
#  'z49',
#  'v49',
#  'x50',
#  'y50',
#  'z50',
#  'v50',
#  'x51',
#  'y51',
#  'z51',
#  'v51',
#  'x52',
#  'y52',
#  'z52',
#  'v52',
#  'x53',
#  'y53',
#  'z53',
#  'v53',
#  'x54',
#  'y54',
#  'z54',
#  'v54',
#  'x55',
#  'y55',
#  'z55',
#  'v55',
#  'x56',
#  'y56',
#  'z56',
#  'v56',
#  'x57',
#  'y57',
#  'z57',
#  'v57',
#  'x58',
#  'y58',
#  'z58',
#  'v58',
#  'x59',
#  'y59',
#  'z59',
#  'v59',
#  'x60',
#  'y60',
#  'z60',
#  'v60',
#  'x61',
#  'y61',
#  'z61',
#  'v61',
#  'x62',
#  'y62',
#  'z62',
#  'v62',
#  'x63',
#  'y63',
#  'z63',
#  'v63',
#  'x64',
#  'y64',
#  'z64',
#  'v64',
#  'x65',
#  'y65',
#  'z65',
#  'v65',
#  'x66',
#  'y66',
#  'z66',
#  'v66',
#  'x67',
#  'y67',
#  'z67',
#  'v67',
#  'x68',
#  'y68',
#  'z68',
#  'v68',
#  'x69',
#  'y69',
#  'z69',
#  'v69',
#  'x70',
#  'y70',
#  'z70',
#  'v70',
#  'x71',
#  'y71',
#  'z71',
#  'v71',
#  'x72',
#  'y72',
#  'z72',
#  'v72',
#  'x73',
#  'y73',
#  'z73',
#  'v73',
#  'x74',
#  'y74',
#  'z74',
#  'v74',
#  'x75',
#  'y75',
#  'z75',
#  'v75',
#  'x76',
#  'y76',
#  'z76',
#  'v76',
#  'x77',
#  'y77',
#  'z77',
#  'v77',
#  'x78',
#  'y78',
#  'z78',
#  'v78',
#  'x79',
#  'y79',
#  'z79',
#  'v79',
#  'x80',
#  'y80',
#  'z80',
#  'v80',
#  'x81',
#  'y81',
#  'z81',
#  'v81',
#  'x82',
#  'y82',
#  'z82',
#  'v82',
#  'x83',
#  'y83',
#  'z83',
#  'v83',
#  'x84',
#  'y84',
#  'z84',
#  'v84',
#  'x85',
#  'y85',
#  'z85',
#  'v85',
#  'x86',
#  'y86',
#  'z86',
#  'v86',
#  'x87',
#  'y87',
#  'z87',
#  'v87',
#  'x88',
#  'y88',
#  'z88',
#  'v88',
#  'x89',
#  'y89',
#  'z89',
#  'v89',
#  'x90',
#  'y90',
#  'z90',
#  'v90',
#  'x91',
#  'y91',
#  'z91',
#  'v91',
#  'x92',
#  'y92',
#  'z92',
#  'v92',
#  'x93',
#  'y93',
#  'z93',
#  'v93',
#  'x94',
#  'y94',
#  'z94',
#  'v94',
#  'x95',
#  'y95',
#  'z95',
#  'v95',
#  'x96',
#  'y96',
#  'z96',
#  'v96',
#  'x97',
#  'y97',
#  'z97',
#  'v97',
#  'x98',
#  'y98',
#  'z98',
#  'v98',
#  'x99',
#  'y99',
#  'z99',
#  'v99',
#  'x100',
#  'y100',
#  'z100',
#  'v100',
#  'x101',
#  'y101',
#  'z101',
#  'v101',
#  'x102',
#  'y102',
#  'z102',
#  'v102',
#  'x103',
#  'y103',
#  'z103',
#  'v103',
#  'x104',
#  'y104',
#  'z104',
#  'v104',
#  'x105',
#  'y105',
#  'z105',
#  'v105',
#  'x106',
#  'y106',
#  'z106',
#  'v106',
#  'x107',
#  'y107',
#  'z107',
#  'v107',
#  'x108',
#  'y108',
#  'z108',
#  'v108',
#  'x109',
#  'y109',
#  'z109',
#  'v109',
#  'x110',
#  'y110',
#  'z110',
#  'v110',
#  'x111',
#  'y111',
#  'z111',
#  'v111',
#  'x112',
#  'y112',
#  'z112',
#  'v112',
#  'x113',
#  'y113',
#  'z113',
#  'v113',
#  'x114',
#  'y114',
#  'z114',
#  'v114',
#  'x115',
#  'y115',
#  'z115',
#  'v115',
#  'x116',
#  'y116',
#  'z116',
#  'v116',
#  'x117',
#  'y117',
#  'z117',
#  'v117',
#  'x118',
#  'y118',
#  'z118',
#  'v118',
#  'x119',
#  'y119',
#  'z119',
#  'v119',
#  'x120',
#  'y120',
#  'z120',
#  'v120',
#  'x121',
#  'y121',
#  'z121',
#  'v121',
#  'x122',
#  'y122',
#  'z122',
#  'v122',
#  'x123',
#  'y123',
#  'z123',
#  'v123',
#  'x124',
#  'y124',
#  'z124',
#  'v124',
#  'x125',
#  'y125',
#  'z125',
#  'v125',
#  'x126',
#  'y126',
#  'z126',
#  'v126',
#  'x127',
#  'y127',
#  'z127',
#  'v127',
#  'x128',
#  'y128',
#  'z128',
#  'v128',
#  'x129',
#  'y129',
#  'z129',
#  'v129',
#  'x130',
#  'y130',
#  'z130',
#  'v130',
#  'x131',
#  'y131',
#  'z131',
#  'v131',
#  'x132',
#  'y132',
#  'z132',
#  'v132',
#  'x133',
#  'y133',
#  'z133',
#  'v133',
#  'x134',
#  'y134',
#  'z134',
#  'v134',
#  'x135',
#  'y135',
#  'z135',
#  'v135',
#  'x136',
#  'y136',
#  'z136',
#  'v136',
#  'x137',
#  'y137',
#  'z137',
#  'v137',
#  'x138',
#  'y138',
#  'z138',
#  'v138',
#  'x139',
#  'y139',
#  'z139',
#  'v139',
#  'x140',
#  'y140',
#  'z140',
#  'v140',
#  'x141',
#  'y141',
#  'z141',
#  'v141',
#  'x142',
#  'y142',
#  'z142',
#  'v142',
#  'x143',
#  'y143',
#  'z143',
#  'v143',
#  'x144',
#  'y144',
#  'z144',
#  'v144',
#  'x145',
#  'y145',
#  'z145',
#  'v145',
#  'x146',
#  'y146',
#  'z146',
#  'v146',
#  'x147',
#  'y147',
#  'z147',
#  'v147',
#  'x148',
#  'y148',
#  'z148',
#  'v148',
#  'x149',
#  'y149',
#  'z149',
#  'v149',
#  'x150',
#  'y150',
#  'z150',
#  'v150',
#  'x151',
#  'y151',
#  'z151',
#  'v151',
#  'x152',
#  'y152',
#  'z152',
#  'v152',
#  'x153',
#  'y153',
#  'z153',
#  'v153',
#  'x154',
#  'y154',
#  'z154',
#  'v154',
#  'x155',
#  'y155',
#  'z155',
#  'v155',
#  'x156',
#  'y156',
#  'z156',
#  'v156',
#  'x157',
#  'y157',
#  'z157',
#  'v157',
#  'x158',
#  'y158',
#  'z158',
#  'v158',
#  'x159',
#  'y159',
#  'z159',
#  'v159',
#  'x160',
#  'y160',
#  'z160',
#  'v160',
#  'x161',
#  'y161',
#  'z161',
#  'v161',
#  'x162',
#  'y162',
#  'z162',
#  'v162',
#  'x163',
#  'y163',
#  'z163',
#  'v163',
#  'x164',
#  'y164',
#  'z164',
#  'v164',
#  'x165',
#  'y165',
#  'z165',
#  'v165',
#  'x166',
#  'y166',
#  'z166',
#  'v166',
#  'x167',
#  'y167',
#  'z167',
#  'v167',
#  'x168',
#  'y168',
#  'z168',
#  'v168',
#  'x169',
#  'y169',
#  'z169',
#  'v169',
#  'x170',
#  'y170',
#  'z170',
#  'v170',
#  'x171',
#  'y171',
#  'z171',
#  'v171',
#  'x172',
#  'y172',
#  'z172',
#  'v172',
#  'x173',
#  'y173',
#  'z173',
#  'v173',
#  'x174',
#  'y174',
#  'z174',
#  'v174',
#  'x175',
#  'y175',
#  'z175',
#  'v175',
#  'x176',
#  'y176',
#  'z176',
#  'v176',
#  'x177',
#  'y177',
#  'z177',
#  'v177',
#  'x178',
#  'y178',
#  'z178',
#  'v178',
#  'x179',
#  'y179',
#  'z179',
#  'v179',
#  'x180',
#  'y180',
#  'z180',
#  'v180',
#  'x181',
#  'y181',
#  'z181',
#  'v181',
#  'x182',
#  'y182',
#  'z182',
#  'v182',
#  'x183',
#  'y183',
#  'z183',
#  'v183',
#  'x184',
#  'y184',
#  'z184',
#  'v184',
#  'x185',
#  'y185',
#  'z185',
#  'v185',
#  'x186',
#  'y186',
#  'z186',
#  'v186',
#  'x187',
#  'y187',
#  'z187',
#  'v187',
#  'x188',
#  'y188',
#  'z188',
#  'v188',
#  'x189',
#  'y189',
#  'z189',
#  'v189',
#  'x190',
#  'y190',
#  'z190',
#  'v190',
#  'x191',
#  'y191',
#  'z191',
#  'v191',
#  'x192',
#  'y192',
#  'z192',
#  'v192',
#  'x193',
#  'y193',
#  'z193',
#  'v193',
#  'x194',
#  'y194',
#  'z194',
#  'v194',
#  'x195',
#  'y195',
#  'z195',
#  'v195',
#  'x196',
#  'y196',
#  'z196',
#  'v196',
#  'x197',
#  'y197',
#  'z197',
#  'v197',
#  'x198',
#  'y198',
#  'z198',
#  'v198',
#  'x199',
#  'y199',
#  'z199',
#  'v199',
#  'x200',
#  'y200',
#  'z200',
#  'v200',
#  'x201',
#  'y201',
#  'z201',
#  'v201',
#  'x202',
#  'y202',
#  'z202',
#  'v202',
#  'x203',
#  'y203',
#  'z203',
#  'v203',
#  'x204',
#  'y204',
#  'z204',
#  'v204',
#  'x205',
#  'y205',
#  'z205',
#  'v205',
#  'x206',
#  'y206',
#  'z206',
#  'v206',
#  'x207',
#  'y207',
#  'z207',
#  'v207',
#  'x208',
#  'y208',
#  'z208',
#  'v208',
#  'x209',
#  'y209',
#  'z209',
#  'v209',
#  'x210',
#  'y210',
#  'z210',
#  'v210',
#  'x211',
#  'y211',
#  'z211',
#  'v211',
#  'x212',
#  'y212',
#  'z212',
#  'v212',
#  'x213',
#  'y213',
#  'z213',
#  'v213',
#  'x214',
#  'y214',
#  'z214',
#  'v214',
#  'x215',
#  'y215',
#  'z215',
#  'v215',
#  'x216',
#  'y216',
#  'z216',
#  'v216',
#  'x217',
#  'y217',
#  'z217',
#  'v217',
#  'x218',
#  'y218',
#  'z218',
#  'v218',
#  'x219',
#  'y219',
#  'z219',
#  'v219',
#  'x220',
#  'y220',
#  'z220',
#  'v220',
#  'x221',
#  'y221',
#  'z221',
#  'v221',
#  'x222',
#  'y222',
#  'z222',
#  'v222',
#  'x223',
#  'y223',
#  'z223',
#  'v223',
#  'x224',
#  'y224',
#  'z224',
#  'v224',
#  'x225',
#  'y225',
#  'z225',
#  'v225',
#  'x226',
#  'y226',
#  'z226',
#  'v226',
#  'x227',
#  'y227',
#  'z227',
#  'v227',
#  'x228',
#  'y228',
#  'z228',
#  'v228',
#  'x229',
#  'y229',
#  'z229',
#  'v229',
#  'x230',
#  'y230',
#  'z230',
#  'v230',
#  'x231',
#  'y231',
#  'z231',
#  'v231',
#  'x232',
#  'y232',
#  'z232',
#  'v232',
#  'x233',
#  'y233',
#  'z233',
#  'v233',
#  'x234',
#  'y234',
#  'z234',
#  'v234',
#  'x235',
#  'y235',
#  'z235',
#  'v235',
#  'x236',
#  'y236',
#  'z236',
#  'v236',
#  'x237',
#  'y237',
#  'z237',
#  'v237',
#  'x238',
#  'y238',
#  'z238',
#  'v238',
#  'x239',
#  'y239',
#  'z239',
#  'v239',
#  'x240',
#  'y240',
#  'z240',
#  'v240',
#  'x241',
#  'y241',
#  'z241',
#  'v241',
#  'x242',
#  'y242',
#  'z242',
#  'v242',
#  'x243',
#  'y243',
#  'z243',
#  'v243',
#  'x244',
#  'y244',
#  'z244',
#  'v244',
#  'x245',
#  'y245',
#  'z245',
#  'v245',
#  'x246',
#  'y246',
#  'z246',
#  'v246',
#  'x247',
#  'y247',
#  'z247',
#  'v247',
#  'x248',
#  'y248',
#  'z248',
#  'v248',
#  'x249',
#  'y249',
#  'z249',
#  'v249',
#  'x250',
#  'y250',
#  'z250',
#  ...]

# %%
# Opened a file called 'coordinates1.csv' in write mode, you can rewrite or rename your csv file/dataset
# to whatever you want.

with open('coordinates1.csv', mode='w', newline='') as f:
    csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
    csv_writer.writerow(landmarks)

# %%
class_name = "Happy"

# %%
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    while cap.isOpened():
        ret, frame = cap.read()

        #Recoloring the Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        #Making Detections
        results = holistic.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        #1. Drawing face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                                  mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                  )

        #2. Right Hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                  )
        #3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                  )
        #4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                  )
        
        #Export Coordinates
        try:
            #Extracting Pose Landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

            #Extracting Face Landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

            #Row Concatenation
            row = pose_row+face_row

            #Appending the class name
            row.insert(0, class_name)

        
            #Exporting to CSV
            with open('coordinates1.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)

        except:
            pass

        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows
# Out:
# I0000 00:00:1720426611.217386   11149 gl_context.cc:357] GL version: 2.1 (2.1 INTEL-22.5.11), renderer: Intel(R) Iris(TM) Plus Graphics OpenGL Engine
# W0000 00:00:1720426611.367670   14725 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426611.391554   14725 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426611.392722   14723 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426611.392726   14721 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426611.393750   14720 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426611.399359   14719 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426611.404796   14723 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426611.412545   14721 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body Language Decoder.ipynb Cell 16 line 1
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X21sZmlsZQ%3D%3D?line=9'>10</a> image.flags.writeable = False
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X21sZmlsZQ%3D%3D?line=11'>12</a> #Making Detections
# ---> <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X21sZmlsZQ%3D%3D?line=12'>13</a> results = holistic.process(image)
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X21sZmlsZQ%3D%3D?line=14'>15</a> image.flags.writeable = True
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X21sZmlsZQ%3D%3D?line=15'>16</a> image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mediapipe/python/solutions/holistic.py:160, in Holistic.process(self, image)
#     136 def process(self, image: np.ndarray) -> NamedTuple:
#     137   """Processes an RGB image and returns the pose landmarks, left and right hand landmarks, and face landmarks on the most prominent person detected.
#     138
#     139   Args:
#    (...)
#     157          "enable_segmentation" is set to true.
#     158   """
# --> 160   results = super().process(input_data={'image': image})
#     161   if results.pose_landmarks:  # pytype: disable=attribute-error
#     162     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mediapipe/python/solution_base.py:340, in SolutionBase.process(self, input_data)
#     334   else:
#     335     self._graph.add_packet_to_input_stream(
#     336         stream=stream_name,
#     337         packet=self._make_packet(input_stream_type,
#     338                                  data).at(self._simulated_timestamp))
# --> 340 self._graph.wait_until_idle()
#     341 # Create a NamedTuple object where the field names are mapping to the graph
#     342 # output stream names.
#     343 if self._output_stream_type_info is None:
#
# KeyboardInterrupt:

# %%
pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

# %%
face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

# %%
row = pose_row+face_row

# %%
row.insert(0, class_name)

# %%
row
# Out:
# ['Happy',
#  0.5409425497055054,
#  0.58708655834198,
#  -1.0503149032592773,
#  0.9996498823165894,
#  0.5630691647529602,
#  0.5208142399787903,
#  -0.9841325879096985,
#  0.9993581175804138,
#  0.5781902074813843,
#  0.521938145160675,
#  -0.984458327293396,
#  0.9993138313293457,
#  0.5931549072265625,
#  0.5235872864723206,
#  -0.9845975637435913,
#  0.9992304444313049,
#  0.5115686655044556,
#  0.5180346369743347,
#  -1.0121698379516602,
#  0.9993752837181091,
#  0.4877617359161377,
#  0.5180653929710388,
#  -1.0116384029388428,
#  0.9994260668754578,
#  0.46831998229026794,
#  0.5193079113960266,
#  -1.012028455734253,
#  0.9994264841079712,
#  0.6119001507759094,
#  0.5611299276351929,
#  -0.5571142435073853,
#  0.9990615248680115,
#  0.4374801218509674,
#  0.5507449507713318,
#  -0.674193263053894,
#  0.9995192289352417,
#  0.5628135800361633,
#  0.6701918244361877,
#  -0.8872763514518738,
#  0.9996718168258667,
#  0.5027194619178772,
#  0.6691055297851562,
#  -0.9222198724746704,


# %%
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    while cap.isOpened():
        ret, frame = cap.read()

        #Recoloring the Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        #Making Detections
        results = holistic.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        #1. Drawing face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                                  mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                  )

        #2. Right Hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                  )
        #3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                  )
        #4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                  )
        
        #Export Coordinates
        try:
            #Extracting Pose Landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

            #Extracting Face Landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

            #Row Concatenation
            row = pose_row+face_row

            #Appending the class name
            row.insert(0, class_name)

        
            #Exporting to CSV
            with open('coordinates1.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)

        except:
            pass

        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows
# Out:
# I0000 00:00:1720426657.246152   11149 gl_context.cc:357] GL version: 2.1 (2.1 INTEL-22.5.11), renderer: Intel(R) Iris(TM) Plus Graphics OpenGL Engine
# W0000 00:00:1720426657.398271   15287 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426657.422262   15287 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426657.423594   15281 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426657.424233   15287 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426657.425753   15288 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426657.432157   15284 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426657.436394   15281 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426657.444959   15287 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body Language Decoder.ipynb Cell 24 line 6
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X32sZmlsZQ%3D%3D?line=62'>63</a>         pass
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X32sZmlsZQ%3D%3D?line=64'>65</a>     cv2.imshow('Raw Webcam Feed', image)
# ---> <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X32sZmlsZQ%3D%3D?line=66'>67</a>     if cv2.waitKey(10) & 0xFF == ord('q'):
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X32sZmlsZQ%3D%3D?line=67'>68</a>         break
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X32sZmlsZQ%3D%3D?line=68'>69</a> cap.release()
#
# KeyboardInterrupt:

# %%
class_name = "Confused"

# %%
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    while cap.isOpened():
        ret, frame = cap.read()

        #Recoloring the Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        #Making Detections
        results = holistic.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        #1. Drawing face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                                  mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                  )

        #2. Right Hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                  )
        #3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                  )
        #4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                  )
        
        #Export Coordinates
        try:
            #Extracting Pose Landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

            #Extracting Face Landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

            #Row Concatenation
            row = pose_row+face_row

            #Appending the class name
            row.insert(0, class_name)

        
            #Exporting to CSV
            with open('coordinates1.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)

        except:
            pass

        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows
# Out:
# I0000 00:00:1720426683.246017   11149 gl_context.cc:357] GL version: 2.1 (2.1 INTEL-22.5.11), renderer: Intel(R) Iris(TM) Plus Graphics OpenGL Engine
# W0000 00:00:1720426683.413475   15622 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426683.439215   15622 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426683.440504   15615 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426683.440955   15616 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426683.441879   15617 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426683.449360   15617 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426683.453779   15615 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426683.463479   15620 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body Language Decoder.ipynb Cell 26 line 6
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X34sZmlsZQ%3D%3D?line=62'>63</a>         pass
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X34sZmlsZQ%3D%3D?line=64'>65</a>     cv2.imshow('Raw Webcam Feed', image)
# ---> <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X34sZmlsZQ%3D%3D?line=66'>67</a>     if cv2.waitKey(10) & 0xFF == ord('q'):
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X34sZmlsZQ%3D%3D?line=67'>68</a>         break
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X34sZmlsZQ%3D%3D?line=68'>69</a> cap.release()
#
# KeyboardInterrupt:

# %%
class_name = "Victorious"

# %%
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    while cap.isOpened():
        ret, frame = cap.read()

        #Recoloring the Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        #Making Detections
        results = holistic.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        #1. Drawing face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                                  mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                  )

        #2. Right Hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                  )
        #3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                  )
        #4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                  )
        
        #Export Coordinates
        try:
            #Extracting Pose Landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

            #Extracting Face Landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

            #Row Concatenation
            row = pose_row+face_row

            #Appending the class name
            row.insert(0, class_name)

        
            #Exporting to CSV
            with open('coordinates1.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)

        except:
            pass

        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows
# Out:
# I0000 00:00:1720426714.101339   11149 gl_context.cc:357] GL version: 2.1 (2.1 INTEL-22.5.11), renderer: Intel(R) Iris(TM) Plus Graphics OpenGL Engine
# W0000 00:00:1720426714.254723   15957 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426714.280179   15961 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426714.281997   15957 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426714.282056   15961 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426714.283028   15963 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426714.289086   15961 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426714.294265   15958 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426714.301694   15959 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body Language Decoder.ipynb Cell 28 line 1
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X36sZmlsZQ%3D%3D?line=9'>10</a> image.flags.writeable = False
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X36sZmlsZQ%3D%3D?line=11'>12</a> #Making Detections
# ---> <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X36sZmlsZQ%3D%3D?line=12'>13</a> results = holistic.process(image)
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X36sZmlsZQ%3D%3D?line=14'>15</a> image.flags.writeable = True
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X36sZmlsZQ%3D%3D?line=15'>16</a> image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mediapipe/python/solutions/holistic.py:160, in Holistic.process(self, image)
#     136 def process(self, image: np.ndarray) -> NamedTuple:
#     137   """Processes an RGB image and returns the pose landmarks, left and right hand landmarks, and face landmarks on the most prominent person detected.
#     138
#     139   Args:
#    (...)
#     157          "enable_segmentation" is set to true.
#     158   """
# --> 160   results = super().process(input_data={'image': image})
#     161   if results.pose_landmarks:  # pytype: disable=attribute-error
#     162     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mediapipe/python/solution_base.py:340, in SolutionBase.process(self, input_data)
#     334   else:
#     335     self._graph.add_packet_to_input_stream(
#     336         stream=stream_name,
#     337         packet=self._make_packet(input_stream_type,
#     338                                  data).at(self._simulated_timestamp))
# --> 340 self._graph.wait_until_idle()
#     341 # Create a NamedTuple object where the field names are mapping to the graph
#     342 # output stream names.
#     343 if self._output_stream_type_info is None:
#
# KeyboardInterrupt:

# %%
class_name = "Shocked"

# %%
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    while cap.isOpened():
        ret, frame = cap.read()

        #Recoloring the Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        #Making Detections
        results = holistic.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        #1. Drawing face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                                  mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                  )

        #2. Right Hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                  )
        #3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                  )
        #4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                  )
        
        #Export Coordinates
        try:
            #Extracting Pose Landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

            #Extracting Face Landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

            #Row Concatenation
            row = pose_row+face_row

            #Appending the class name
            row.insert(0, class_name)

        
            #Exporting to CSV
            with open('coordinates1.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)

        except:
            pass

        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows
# Out:
# I0000 00:00:1720426733.560051   11149 gl_context.cc:357] GL version: 2.1 (2.1 INTEL-22.5.11), renderer: Intel(R) Iris(TM) Plus Graphics OpenGL Engine
# W0000 00:00:1720426733.722267   16197 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426733.746005   16195 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426733.747201   16191 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426733.747201   16196 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426733.748050   16197 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426733.754709   16197 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426733.759839   16196 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426733.767580   16191 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body Language Decoder.ipynb Cell 30 line 1
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X41sZmlsZQ%3D%3D?line=9'>10</a> image.flags.writeable = False
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X41sZmlsZQ%3D%3D?line=11'>12</a> #Making Detections
# ---> <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X41sZmlsZQ%3D%3D?line=12'>13</a> results = holistic.process(image)
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X41sZmlsZQ%3D%3D?line=14'>15</a> image.flags.writeable = True
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X41sZmlsZQ%3D%3D?line=15'>16</a> image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mediapipe/python/solutions/holistic.py:160, in Holistic.process(self, image)
#     136 def process(self, image: np.ndarray) -> NamedTuple:
#     137   """Processes an RGB image and returns the pose landmarks, left and right hand landmarks, and face landmarks on the most prominent person detected.
#     138
#     139   Args:
#    (...)
#     157          "enable_segmentation" is set to true.
#     158   """
# --> 160   results = super().process(input_data={'image': image})
#     161   if results.pose_landmarks:  # pytype: disable=attribute-error
#     162     for landmark in results.pose_landmarks.landmark:  # pytype: disable=attribute-error
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mediapipe/python/solution_base.py:340, in SolutionBase.process(self, input_data)
#     334   else:
#     335     self._graph.add_packet_to_input_stream(
#     336         stream=stream_name,
#     337         packet=self._make_packet(input_stream_type,
#     338                                  data).at(self._simulated_timestamp))
# --> 340 self._graph.wait_until_idle()
#     341 # Create a NamedTuple object where the field names are mapping to the graph
#     342 # output stream names.
#     343 if self._output_stream_type_info is None:
#
# KeyboardInterrupt:

# %%
class_name = "Angry"

# %%
cap = cv2.VideoCapture(0)

with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    while cap.isOpened():
        ret, frame = cap.read()

        #Recoloring the Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        #Making Detections
        results = holistic.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        #1. Drawing face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                                  mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                  )

        #2. Right Hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                  )
        #3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                  )
        #4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                  )
        
        #Export Coordinates
        try:
            #Extracting Pose Landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

            #Extracting Face Landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

            #Row Concatenation
            row = pose_row+face_row

            #Appending the class name
            row.insert(0, class_name)

        
            #Exporting to CSV
            with open('coordinates1.csv', mode='a', newline='') as f:
                csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                csv_writer.writerow(row)

        except:
            pass

        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows
# Out:
# I0000 00:00:1720426762.968308   11149 gl_context.cc:357] GL version: 2.1 (2.1 INTEL-22.5.11), renderer: Intel(R) Iris(TM) Plus Graphics OpenGL Engine
# W0000 00:00:1720426763.119780   16543 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426763.144900   16543 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426763.146427   16544 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426763.146449   16546 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426763.147856   16541 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426763.153131   16541 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426763.157950   16544 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720426763.166730   16546 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body Language Decoder.ipynb Cell 32 line 6
#       <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X43sZmlsZQ%3D%3D?line=2'>3</a> with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:
#       <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X43sZmlsZQ%3D%3D?line=4'>5</a>     while cap.isOpened():
# ----> <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X43sZmlsZQ%3D%3D?line=5'>6</a>         ret, frame = cap.read()
#       <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X43sZmlsZQ%3D%3D?line=7'>8</a>         #Recoloring the Feed
#       <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#X43sZmlsZQ%3D%3D?line=8'>9</a>         image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#
# KeyboardInterrupt:

# %% [markdown]
# # 3. Train Custom Model Using Scikit Learn

# %% [markdown]
# ## 3.1 Read in Collected Data and Process

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# Using Pandas to read a CSV file into a DataFrame

# %%
df = pd.read_csv('coordinates1.csv')

# %%
df.head()
# Out:
#    class        x1        y1        z1        v1        x2        y2  \
# 0  Happy  0.550526  0.584428 -0.942876  0.999772  0.571894  0.519144
# 1  Happy  0.543595  0.587273 -1.135535  0.999747  0.567740  0.521233
# 2  Happy  0.538376  0.589287 -1.184265  0.999742  0.564486  0.522800
# 3  Happy  0.536999  0.590986 -1.151393  0.999729  0.563500  0.523967
# 4  Happy  0.533405  0.590362 -1.176427  0.999719  0.560908  0.523829
#
#          z2        v2        x3  ...      z499  v499      x500      y500  \
# 0 -0
# 351   0.016235   0.0  0.598670  0.480913  0.016957   0.0
# 1370  0.016318   0.0  0.599088  0.551272  0.017478   0.0
# 564   0.009727   0.0  0.616297  0.530890  0.010114   0.0
# ...        ...   ...       ...       ...       ...   ...
# 301   0.014382   0.0  0.604459  0.493226  0.015052   0.0
# 985   0.022118   0.0  0.604460  0.545164  0.023371   0.0
# 1080  0.019607   0.0  0.598500  0.549879  0.020880   0.0
# 83    0.020468   0.0  0.593491  0.437321  0.021741   0.0
# 456   0.017395   0.0  0.605025  0.483258  0.018114   0.0
#
# [450 rows x 2004 columns]

# %%
y_train
# Out:
# 413            Sad
# 62           Happy
# 764     Victorious
# 577       Confused
# 858     Victorious
#            ...
# 1228       Shocked
# 1077       Shocked
# 1318         Angry
# 723       Confused
# 815     Victorious
# Name: class, Length: 1048, dtype: object

# %%
y_test
# Out:
# 78         Happy
# 366          Sad
# 351          Sad
# 1370       Angry
# 564     Confused
#           ...
# 301          Sad
# 985      Shocked
# 1080     Shocked
# 83         Happy
# 456          Sad
# Name: class, Length: 450, dtype: object

# %% [markdown]
# # 3.2 Training ML Learning Classification Model

# %%
from sklearn.pipeline import make_pipeline 
from sklearn.preprocessing import StandardScaler 

from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %% [markdown]
# Building Pipelines to 4 different types of Algorithims
#
# Here are the 4 types of Algorithims
# 1. LogisitcRegression
# 2. RidgeClassification
# 3. RandomForestClassification
# 4. GradientBoostingClassification

# %%
#Implementing the 4 types of Algorithms here, for our 4 pipelines
pipelines = {
    'lr':make_pipeline(StandardScaler(), LogisticRegression()),
    'rc':make_pipeline(StandardScaler(), RidgeClassifier()),
    'rf':make_pipeline(StandardScaler(), RandomForestClassifier()),
    'gb':make_pipeline(StandardScaler(), GradientBoostingClassifier()),
}

# %%
# Method in Sci-Kit which return a list of the names in the pipelines
# For us this is the list of Algorithm
pipelines.keys()
# Out:
# dict_keys(['lr', 'rc', 'rf', 'gb'])

# %%
# Visualizing/Listing the Pipelines index value of 0 from the list, you can visualize the rest.

list(pipelines.values())[0]
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('logisticregression', LogisticRegression())])

# %% [markdown]
# # Training the Model

# %% [markdown]
# **The rutime for this code below took an astounding 14 min on my local pc, be aware that this may take some time. It all really depends on your PC model.**

# %%
#Creating an empty dictionary to store the fitted models, then iterating through the list of pipelines
# Fitting each pipeline to the training data at hand, then storing it in a dictionary
fit_models = {}
for algo, pipeline in pipelines.items():
    model = pipeline.fit(X_train, y_train)
    fit_models[algo] = model

# %%
fit_models
# Out:
# {'lr': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression', LogisticRegression())]),
#  'rc': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('ridgeclassifier', RidgeClassifier())]),
#  'rf': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier', RandomForestClassifier())]),
#  'gb': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('gradientboostingclassifier', GradientBoostingClassifier())])}

# %% [markdown]
# # Testing the Models

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['Happy', 'Sad', 'Sad', 'Angry', 'Confused', 'Victorious', 'Happy',
#        'Angry', 'Sad', 'Confused', 'Shocked', 'Victorious', 'Shocked',
#        'Shocked', 'Angry', 'Shocked', 'Victorious', 'Shocked',
#        'Victorious', 'Victorious', 'Confused', 'Angry', 'Happy', 'Happy',
#        'Shocked', 'Shocked', 'Shocked', 'Shocked', 'Angry', 'Angry',
#        'Angry', 'Happy', 'Shocked', 'Victorious', 'Happy', 'Happy',
#        'Victorious', 'Confused', 'Happy', 'Happy', 'Shocked', 'Confused',
#        'Shocked', 'Happy', 'Confused', 'Happy', 'Confused', 'Happy',
#        'Happy', 'Confused', 'Sad', 'Sad', 'Sad', 'Sad', 'Confused',
#        'Happy', 'Angry', 'Happy', 'Angry', 'Confused', 'Confused',
#        'Shocked', 'Shocked', 'Sad', 'Confused', 'Shocked', 'Victorious',
#        'Confused', 'Confused', 'Shocked', 'Sad', 'Sad', 'Confused',
#        'Confused', 'Confused', 'Angry', 'Victorious', 'Confused',
#        'Confused', 'Angry', 'Confused', 'Victorious', 'Happy', 'Angry',
#        'Sad', 'Sad', 'Happy', 'Confused', 'Sad', 'Confused', 'Confused',
#        'Sad', 'Shocked', 'Shocked', 'Happy', 'Shocked', 'Angry', 'Angry',
#        'Confused', 'Confused', 'Shocked', 'Victorious', 'Victorious',
#        'Victorious', 'Confused', 'Shocked', 'Happy', 'Confused',
#        'Shocked', 'Shocked', 'Shocked', 'Happy', 'Victorious',
#        'Victorious', 'Angry', 'Happy', 'Shocked', 'Victorious', 'Angry',
#        'Angry', 'Victorious', 'Happy', 'Confused', 'Shocked', 'Confused',
#        'Shocked', 'Sad', 'Sad', 'Victorious', 'Happy', 'Confused',
#        'Victorious', 'Confused', 'Angry', 'Shocked', 'Confused',
#        'Confused', 'Confused', 'Confused', 'Confused', 'Victorious',
#        'Angry', 'Shocked', 'Confused', 'Angry', 'Happy', 'Angry', 'Happy',
#        'Shocked', 'Happy', 'Happy', 'Victorious', 'Shocked', 'Shocked',
#        'Shocked', 'Sad', 'Happy', 'Confused', 'Angry', 'Sad', 'Confused',
#        'Angry', 'Victorious', 'Angry', 'Happy', 'Sad', 'Sad', 'Happy',
#        'Happy', 'Sad', 'Happy', 'Shocked', 'Angry', 'Happy', 'Confused',
#        'Victorious', 'Happy', 'Victorious', 'Confused', 'Confused',
#        'Happy', 'Angry', 'Shocked', 'Confused', 'Victorious', 'Sad',
#        'Victorious', 'Sad', 'Shocked', 'Shocked', 'Shocked', 'Shocked',
#        'Happy', 'Sad', 'Angry', 'Happy', 'Shocked', 'Victorious',
#        'Confused', 'Confused', 'Angry', 'Shocked', 'Sad', 'Angry',
#        'Victorious', 'Sad', 'Sad', 'Sad', 'Confused', 'Angry', 'Angry',
#        'Sad', 'Confused', 'Sad', 'Sad', 'Happy', 'Shocked', 'Angry',
#        'Angry', 'Happy', 'Confused', 'Shocked', 'Sad', 'Sad', 'Sad',
#        'Shocked', 'Confused', 'Happy', 'Confused', 'Happy', 'Shocked',
#        'Happy', 'Happy', 'Shocked', 'Victorious', 'Shocked', 'Angry',
#        'Sad', 'Victorious', 'Sad', 'Sad', 'Confused', 'Shocked', 'Happy',
#        'Sad', 'Shocked', 'Confused', 'Confused', 'Shocked', 'Confused',
#        'Angry', 'Happy', 'Victorious', 'Victorious', 'Confused', 'Sad',
#        'Happy', 'Sad', 'Sad', 'Shocked', 'Shocked', 'Confused',
#        'Confused', 'Shocked', 'Shocked', 'Angry', 'Happy', 'Confused',
#        'Confused', 'Confused', 'Shocked', 'Shocked', 'Happy',
#        'Victorious', 'Victorious', 'Victorious', 'Happy', 'Sad', 'Sad',
#        'Victorious', 'Shocked', 'Sad', 'Angry', 'Angry', 'Angry',
#        'Shocked', 'Angry', 'Angry', 'Shocked', 'Confused', 'Angry',
#        'Happy', 'Shocked', 'Happy', 'Sad', 'Confused', 'Happy', 'Happy',
#        'Happy', 'Angry', 'Victorious', 'Confused', 'Confused', 'Shocked',
#        'Confused', 'Happy', 'Victorious', 'Angry', 'Victorious',
#        'Confused', 'Confused', 'Happy', 'Sad', 'Happy', 'Angry', 'Angry',
#        'Shocked', 'Angry', 'Angry', 'Happy', 'Angry', 'Sad', 'Happy',
#        'Angry', 'Happy', 'Confused', 'Shocked', 'Happy', 'Sad',
#        'Victorious', 'Angry', 'Shocked', 'Happy', 'Confused', 'Happy',
#        'Shocked', 'Happy', 'Confused', 'Angry', 'Happy', 'Angry',
#        'Shocked', 'Victorious', 'Shocked', 'Happy', 'Angry', 'Confused',
#        'Angry', 'Confused', 'Happy', 'Angry', 'Happy', 'Victorious',
#        'Shocked', 'Victorious', 'Angry', 'Sad', 'Shocked', 'Happy', 'Sad',
#        'Sad', 'Sad', 'Shocked', 'Confused', 'Shocked', 'Angry',
#        'Confused', 'Shocked', 'Shocked', 'Shocked', 'Sad', 'Happy',
#        'Victorious', 'Victorious', 'Angry', 'Angry', 'Shocked',
#        'Victorious', 'Angry', 'Happy', 'Shocked', 'Sad', 'Angry',
#        'Victorious', 'Sad', 'Angry', 'Shocked', 'Confused', 'Victorious',
#        'Confused', 'Shocked', 'Happy', 'Sad', 'Angry', 'Confused',
#        'Angry', 'Happy', 'Shocked', 'Shocked', 'Confused', 'Happy',
#        'Shocked', 'Shocked', 'Sad', 'Victorious', 'Confused', 'Confused',
#        'Angry', 'Angry', 'Shocked', 'Victorious', 'Angry', 'Shocked',
#        'Shocked', 'Happy', 'Sad', 'Shocked', 'Shocked', 'Confused',
#        'Angry', 'Confused', 'Shocked', 'Confused', 'Sad', 'Sad', 'Happy',
#        'Happy', 'Sad', 'Confused', 'Angry', 'Angry', 'Happy', 'Angry',
#        'Shocked', 'Sad', 'Shocked', 'Angry', 'Confused', 'Happy',
#        'Confused', 'Happy', 'Sad', 'Shocked', 'Shocked', 'Victorious',
#        'Sad', 'Shocked', 'Shocked', 'Happy', 'Sad'], dtype=object)

# %%
fit_models['gb'].predict(X_test)
# Out:
# array(['Happy', 'Sad', 'Sad', 'Angry', 'Confused', 'Victorious', 'Happy',
#        'Angry', 'Sad', 'Confused', 'Shocked', 'Victorious', 'Shocked',
#        'Shocked', 'Angry', 'Shocked', 'Victorious', 'Shocked',
#        'Victorious', 'Victorious', 'Confused', 'Angry', 'Happy', 'Happy',
#        'Shocked', 'Shocked', 'Shocked', 'Shocked', 'Angry', 'Angry',
#        'Angry', 'Happy', 'Shocked', 'Victorious', 'Happy', 'Happy',
#        'Victorious', 'Confused', 'Happy', 'Happy', 'Shocked', 'Confused',
#        'Shocked', 'Happy', 'Confused', 'Happy', 'Confused', 'Happy',
#        'Happy', 'Confused', 'Sad', 'Sad', 'Sad', 'Sad', 'Confused',
#        'Happy', 'Angry', 'Happy', 'Angry', 'Confused', 'Confused',
#        'Shocked', 'Shocked', 'Sad', 'Confused', 'Shocked', 'Victorious',
#        'Confused', 'Confused', 'Shocked', 'Sad', 'Sad', 'Confused',
#        'Confused', 'Confused', 'Angry', 'Victorious', 'Confused',
#        'Confused', 'Angry', 'Confused', 'Victorious', 'Happy', 'Angry',
#        'Sad', 'Sad', 'Happy', 'Confused', 'Sad', 'Confused', 'Confused',
#        'Sad', 'Shocked', 'Shocked', 'Happy', 'Shocked', 'Angry', 'Angry',
#        'Confused', 'Confused', 'Shocked', 'Victorious', 'Victorious',
#        'Victorious', 'Confused', 'Shocked', 'Happy', 'Confused',
#        'Shocked', 'Shocked', 'Shocked', 'Happy', 'Victorious', 'Sad',
#        'Angry', 'Happy', 'Shocked', 'Victorious', 'Angry', 'Angry',
#        'Victorious', 'Happy', 'Confused', 'Shocked', 'Shocked', 'Shocked',
#        'Sad', 'Sad', 'Victorious', 'Happy', 'Confused', 'Victorious',
#        'Confused', 'Angry', 'Shocked', 'Confused', 'Confused', 'Confused',
#        'Confused', 'Confused', 'Victorious', 'Angry', 'Shocked',
#        'Confused', 'Angry', 'Happy', 'Angry', 'Happy', 'Shocked', 'Happy',
#        'Happy', 'Victorious', 'Shocked', 'Shocked', 'Shocked', 'Sad',
#        'Happy', 'Confused', 'Angry', 'Sad', 'Confused', 'Angry',
#        'Victorious', 'Angry', 'Happy', 'Sad', 'Sad', 'Happy', 'Happy',
#        'Sad', 'Happy', 'Shocked', 'Angry', 'Happy', 'Confused',
#        'Victorious', 'Happy', 'Victorious', 'Confused', 'Confused',
#        'Happy', 'Angry', 'Shocked', 'Confused', 'Victorious', 'Sad',
#        'Victorious', 'Sad', 'Shocked', 'Shocked', 'Shocked', 'Shocked',
#        'Happy', 'Sad', 'Angry', 'Happy', 'Shocked', 'Victorious',
#        'Confused', 'Confused', 'Angry', 'Shocked', 'Sad', 'Angry',
#        'Victorious', 'Sad', 'Sad', 'Sad', 'Confused', 'Angry', 'Angry',
#        'Sad', 'Confused', 'Sad', 'Sad', 'Happy', 'Shocked', 'Angry',
#        'Angry', 'Happy', 'Confused', 'Shocked', 'Sad', 'Sad', 'Sad',
#        'Shocked', 'Confused', 'Happy', 'Confused', 'Happy', 'Shocked',
#        'Happy', 'Happy', 'Shocked', 'Victorious', 'Shocked', 'Angry',
#        'Sad', 'Victorious', 'Sad', 'Sad', 'Confused', 'Shocked', 'Happy',
#        'Sad', 'Shocked', 'Confused', 'Confused', 'Shocked', 'Confused',
#        'Angry', 'Happy', 'Victorious', 'Victorious', 'Confused', 'Sad',
#        'Happy', 'Sad', 'Sad', 'Shocked', 'Shocked', 'Confused',
#        'Confused', 'Shocked', 'Shocked', 'Angry', 'Happy', 'Confused',
#        'Confused', 'Confused', 'Shocked', 'Shocked', 'Happy',
#        'Victorious', 'Victorious', 'Victorious', 'Happy', 'Sad', 'Sad',
#        'Victorious', 'Shocked', 'Sad', 'Angry', 'Angry', 'Angry', 'Happy',
#        'Angry', 'Angry', 'Shocked', 'Confused', 'Angry', 'Happy',
#        'Shocked', 'Happy', 'Sad', 'Confused', 'Happy', 'Happy', 'Happy',
#        'Angry', 'Victorious', 'Confused', 'Confused', 'Shocked',
#        'Confused', 'Happy', 'Victorious', 'Angry', 'Victorious',
#        'Confused', 'Confused', 'Happy', 'Sad', 'Happy', 'Angry', 'Angry',
#        'Shocked', 'Angry', 'Angry', 'Happy', 'Angry', 'Sad', 'Happy',
#        'Angry', 'Happy', 'Confused', 'Shocked', 'Happy', 'Sad',
#        'Victorious', 'Angry', 'Shocked', 'Happy', 'Confused', 'Happy',
#        'Shocked', 'Happy', 'Confused', 'Angry', 'Happy', 'Angry',
#        'Shocked', 'Victorious', 'Shocked', 'Happy', 'Angry', 'Confused',
#        'Angry', 'Confused', 'Happy', 'Angry', 'Happy', 'Victorious',
#        'Shocked', 'Victorious', 'Angry', 'Sad', 'Shocked', 'Happy', 'Sad',
#        'Sad', 'Sad', 'Shocked', 'Confused', 'Shocked', 'Angry',
#        'Confused', 'Shocked', 'Shocked', 'Shocked', 'Sad', 'Happy',
#        'Victorious', 'Victorious', 'Angry', 'Angry', 'Shocked',
#        'Victorious', 'Angry', 'Happy', 'Shocked', 'Sad', 'Angry',
#        'Victorious', 'Sad', 'Angry', 'Shocked', 'Confused', 'Victorious',
#        'Confused', 'Shocked', 'Happy', 'Sad', 'Angry', 'Confused',
#        'Angry', 'Happy', 'Shocked', 'Shocked', 'Confused', 'Happy',
#        'Shocked', 'Shocked', 'Sad', 'Victorious', 'Confused', 'Confused',
#        'Angry', 'Angry', 'Shocked', 'Sad', 'Angry', 'Shocked', 'Shocked',
#        'Happy', 'Sad', 'Shocked', 'Shocked', 'Confused', 'Angry',
#        'Confused', 'Shocked', 'Confused', 'Sad', 'Sad', 'Happy', 'Happy',
#        'Sad', 'Confused', 'Angry', 'Angry', 'Happy', 'Angry', 'Shocked',
#        'Sad', 'Shocked', 'Angry', 'Confused', 'Happy', 'Confused',
#        'Happy', 'Sad', 'Shocked', 'Shocked', 'Victorious', 'Sad',
#        'Shocked', 'Shocked', 'Happy', 'Sad'], dtype=object)

# %%
fit_models['rc'].predict(X_test)
# Out:
# array(['Happy', 'Sad', 'Sad', 'Angry', 'Confused', 'Victorious', 'Happy',
#        'Angry', 'Sad', 'Confused', 'Shocked', 'Victorious', 'Shocked',
#        'Shocked', 'Angry', 'Shocked', 'Victorious', 'Shocked',
#        'Victorious', 'Victorious', 'Confused', 'Angry', 'Happy', 'Happy',
#        'Shocked', 'Shocked', 'Shocked', 'Shocked', 'Angry', 'Angry',
#        'Angry', 'Happy', 'Shocked', 'Victorious', 'Happy', 'Happy',
#        'Victorious', 'Confused', 'Happy', 'Happy', 'Shocked', 'Confused',
#        'Shocked', 'Happy', 'Confused', 'Happy', 'Confused', 'Happy',
#        'Happy', 'Confused', 'Sad', 'Sad', 'Sad', 'Sad', 'Confused',
#        'Happy', 'Angry', 'Happy', 'Angry', 'Confused', 'Confused',
#        'Shocked', 'Shocked', 'Sad', 'Confused', 'Shocked', 'Victorious',
#        'Confused', 'Confused', 'Shocked', 'Sad', 'Sad', 'Confused',
#        'Confused', 'Confused', 'Angry', 'Victorious', 'Confused',
#        'Confused', 'Angry', 'Confused', 'Victorious', 'Happy', 'Angry',
#        'Sad', 'Sad', 'Happy', 'Confused', 'Sad', 'Confused', 'Confused',
#        'Sad', 'Shocked', 'Shocked', 'Happy', 'Shocked', 'Angry', 'Angry',
#        'Confused', 'Confused', 'Shocked', 'Victorious', 'Victorious',
#        'Victorious', 'Confused', 'Shocked', 'Happy', 'Confused',
#        'Shocked', 'Shocked', 'Shocked', 'Happy', 'Victorious', 'Sad',
#        'Angry', 'Happy', 'Shocked', 'Victorious', 'Angry', 'Angry',
#        'Victorious', 'Happy', 'Confused', 'Shocked', 'Confused',
#        'Shocked', 'Sad', 'Sad', 'Victorious', 'Happy', 'Confused',
#        'Victorious', 'Confused', 'Angry', 'Shocked', 'Confused',
#        'Confused', 'Confused', 'Confused', 'Confused', 'Victorious',
#        'Angry', 'Shocked', 'Confused', 'Angry', 'Happy', 'Angry', 'Happy',
#        'Shocked', 'Happy', 'Happy', 'Victorious', 'Shocked', 'Shocked',
#        'Shocked', 'Sad', 'Happy', 'Confused', 'Angry', 'Sad', 'Confused',
#        'Angry', 'Victorious', 'Angry', 'Happy', 'Sad', 'Sad', 'Happy',
#        'Happy', 'Sad', 'Happy', 'Shocked', 'Angry', 'Happy', 'Confused',
#        'Victorious', 'Happy', 'Victorious', 'Confused', 'Confused',
#        'Happy', 'Angry', 'Shocked', 'Confused', 'Victorious', 'Sad',
#        'Victorious', 'Sad', 'Shocked', 'Shocked', 'Shocked', 'Shocked',
#        'Happy', 'Sad', 'Angry', 'Happy', 'Shocked', 'Victorious',
#        'Confused', 'Confused', 'Angry', 'Shocked', 'Sad', 'Angry',
#        'Victorious', 'Sad', 'Sad', 'Sad', 'Confused', 'Angry', 'Angry',
#        'Sad', 'Confused', 'Sad', 'Sad', 'Happy', 'Shocked', 'Angry',
#        'Angry', 'Happy', 'Confused', 'Shocked', 'Sad', 'Sad', 'Sad',
#        'Shocked', 'Confused', 'Happy', 'Confused', 'Happy', 'Shocked',
#        'Happy', 'Happy', 'Shocked', 'Victorious', 'Shocked', 'Angry',
#        'Sad', 'Victorious', 'Sad', 'Sad', 'Confused', 'Shocked', 'Happy',
#        'Sad', 'Shocked', 'Confused', 'Confused', 'Shocked', 'Confused',
#        'Angry', 'Happy', 'Victorious', 'Victorious', 'Confused', 'Sad',
#        'Happy', 'Sad', 'Sad', 'Shocked', 'Shocked', 'Confused',
#        'Confused', 'Shocked', 'Shocked', 'Angry', 'Happy', 'Confused',
#        'Confused', 'Confused', 'Shocked', 'Shocked', 'Happy',
#        'Victorious', 'Victorious', 'Victorious', 'Happy', 'Sad', 'Sad',
#        'Victorious', 'Shocked', 'Sad', 'Angry', 'Angry', 'Angry',
#        'Shocked', 'Angry', 'Angry', 'Shocked', 'Confused', 'Angry',
#        'Happy', 'Shocked', 'Happy', 'Sad', 'Confused', 'Happy', 'Happy',
#        'Happy', 'Angry', 'Victorious', 'Confused', 'Confused', 'Shocked',
#        'Confused', 'Happy', 'Victorious', 'Angry', 'Victorious',
#        'Confused', 'Confused', 'Happy', 'Sad', 'Happy', 'Angry', 'Angry',
#        'Shocked', 'Angry', 'Angry', 'Happy', 'Angry', 'Sad', 'Happy',
#        'Angry', 'Happy', 'Confused', 'Shocked', 'Happy', 'Sad',
#        'Victorious', 'Angry', 'Shocked', 'Happy', 'Confused', 'Happy',
#        'Shocked', 'Happy', 'Confused', 'Angry', 'Happy', 'Angry',
#        'Shocked', 'Victorious', 'Shocked', 'Happy', 'Angry', 'Confused',
#        'Angry', 'Confused', 'Happy', 'Angry', 'Happy', 'Victorious',
#        'Shocked', 'Victorious', 'Angry', 'Sad', 'Shocked', 'Happy', 'Sad',
#        'Sad', 'Sad', 'Shocked', 'Confused', 'Shocked', 'Angry',
#        'Confused', 'Shocked', 'Shocked', 'Shocked', 'Sad', 'Happy',
#        'Victorious', 'Victorious', 'Angry', 'Angry', 'Shocked',
#        'Victorious', 'Angry', 'Happy', 'Shocked', 'Sad', 'Angry',
#        'Victorious', 'Sad', 'Angry', 'Shocked', 'Confused', 'Victorious',
#        'Confused', 'Shocked', 'Happy', 'Sad', 'Angry', 'Confused',
#        'Angry', 'Happy', 'Shocked', 'Shocked', 'Confused', 'Happy',
#        'Shocked', 'Shocked', 'Sad', 'Victorious', 'Confused', 'Confused',
#        'Angry', 'Angry', 'Shocked', 'Sad', 'Angry', 'Shocked', 'Shocked',
#        'Happy', 'Sad', 'Shocked', 'Shocked', 'Confused', 'Angry',
#        'Confused', 'Shocked', 'Confused', 'Sad', 'Sad', 'Happy', 'Happy',
#        'Sad', 'Confused', 'Angry', 'Angry', 'Happy', 'Angry', 'Shocked',
#        'Sad', 'Shocked', 'Angry', 'Confused', 'Happy', 'Confused',
#        'Happy', 'Sad', 'Shocked', 'Shocked', 'Victorious', 'Sad',
#        'Shocked', 'Shocked', 'Happy', 'Sad'], dtype='<U10')

# %%
fit_models['lr'].predict(X_test)
# Out:
# array(['Happy', 'Sad', 'Sad', 'Angry', 'Confused', 'Victorious', 'Happy',
#        'Angry', 'Sad', 'Confused', 'Shocked', 'Victorious', 'Shocked',
#        'Shocked', 'Angry', 'Shocked', 'Victorious', 'Shocked',
#        'Victorious', 'Victorious', 'Confused', 'Angry', 'Happy', 'Happy',
#        'Shocked', 'Shocked', 'Shocked', 'Shocked', 'Angry', 'Angry',
#        'Angry', 'Happy', 'Shocked', 'Victorious', 'Happy', 'Happy',
#        'Victorious', 'Confused', 'Happy', 'Happy', 'Shocked', 'Confused',
#        'Shocked', 'Happy', 'Confused', 'Happy', 'Confused', 'Happy',
#        'Happy', 'Confused', 'Sad', 'Sad', 'Sad', 'Sad', 'Confused',
#        'Happy', 'Angry', 'Happy', 'Angry', 'Confused', 'Confused',
#        'Shocked', 'Shocked', 'Sad', 'Confused', 'Shocked', 'Victorious',
#        'Confused', 'Confused', 'Shocked', 'Sad', 'Sad', 'Confused',
#        'Confused', 'Confused', 'Angry', 'Victorious', 'Confused',
#        'Confused', 'Angry', 'Confused', 'Victorious', 'Happy', 'Angry',
#        'Sad', 'Sad', 'Happy', 'Confused', 'Sad', 'Confused', 'Confused',
#        'Sad', 'Shocked', 'Shocked', 'Happy', 'Shocked', 'Angry', 'Angry',
#        'Confused', 'Confused', 'Shocked', 'Victorious', 'Victorious',
#        'Victorious', 'Confused', 'Shocked', 'Happy', 'Confused',
#        'Shocked', 'Shocked', 'Shocked', 'Happy', 'Victorious', 'Sad',
#        'Angry', 'Happy', 'Shocked', 'Victorious', 'Angry', 'Angry',
#        'Victorious', 'Happy', 'Confused', 'Shocked', 'Confused',
#        'Shocked', 'Sad', 'Sad', 'Victorious', 'Happy', 'Confused',
#        'Victorious', 'Confused', 'Angry', 'Shocked', 'Confused',
#        'Confused', 'Confused', 'Confused', 'Confused', 'Victorious',
#        'Angry', 'Shocked', 'Confused', 'Angry', 'Happy', 'Angry', 'Happy',
#        'Shocked', 'Happy', 'Happy', 'Victorious', 'Shocked', 'Shocked',
#        'Shocked', 'Sad', 'Happy', 'Confused', 'Angry', 'Sad', 'Confused',
#        'Angry', 'Victorious', 'Angry', 'Happy', 'Sad', 'Sad', 'Happy',
#        'Happy', 'Sad', 'Happy', 'Shocked', 'Angry', 'Happy', 'Confused',
#        'Victorious', 'Happy', 'Victorious', 'Confused', 'Confused',
#        'Happy', 'Angry', 'Shocked', 'Confused', 'Victorious', 'Sad',
#        'Victorious', 'Sad', 'Shocked', 'Shocked', 'Shocked', 'Shocked',
#        'Happy', 'Sad', 'Angry', 'Happy', 'Shocked', 'Victorious',
#        'Confused', 'Confused', 'Angry', 'Shocked', 'Sad', 'Angry',
#        'Victorious', 'Sad', 'Sad', 'Sad', 'Confused', 'Angry', 'Angry',
#        'Sad', 'Confused', 'Sad', 'Sad', 'Happy', 'Shocked', 'Angry',
#        'Angry', 'Happy', 'Confused', 'Shocked', 'Sad', 'Sad', 'Sad',
#        'Shocked', 'Confused', 'Happy', 'Confused', 'Happy', 'Shocked',
#        'Happy', 'Happy', 'Shocked', 'Victorious', 'Shocked', 'Angry',
#        'Sad', 'Victorious', 'Sad', 'Sad', 'Confused', 'Shocked', 'Happy',
#        'Sad', 'Shocked', 'Confused', 'Confused', 'Shocked', 'Confused',
#        'Angry', 'Happy', 'Victorious', 'Victorious', 'Confused', 'Sad',
#        'Happy', 'Sad', 'Sad', 'Shocked', 'Shocked', 'Confused',
#        'Confused', 'Shocked', 'Shocked', 'Angry', 'Happy', 'Confused',
#        'Confused', 'Confused', 'Shocked', 'Shocked', 'Happy',
#        'Victorious', 'Victorious', 'Victorious', 'Happy', 'Sad', 'Sad',
#        'Victorious', 'Shocked', 'Sad', 'Angry', 'Angry', 'Angry',
#        'Shocked', 'Angry', 'Angry', 'Shocked', 'Confused', 'Angry',
#        'Happy', 'Shocked', 'Happy', 'Sad', 'Confused', 'Happy', 'Happy',
#        'Happy', 'Angry', 'Victorious', 'Confused', 'Confused', 'Shocked',
#        'Confused', 'Happy', 'Victorious', 'Angry', 'Victorious',
#        'Confused', 'Confused', 'Happy', 'Sad', 'Happy', 'Angry', 'Angry',
#        'Shocked', 'Angry', 'Angry', 'Happy', 'Angry', 'Sad', 'Happy',
#        'Angry', 'Happy', 'Confused', 'Shocked', 'Happy', 'Sad',
#        'Victorious', 'Angry', 'Shocked', 'Happy', 'Confused', 'Happy',
#        'Shocked', 'Happy', 'Confused', 'Angry', 'Happy', 'Angry',
#        'Shocked', 'Victorious', 'Shocked', 'Happy', 'Angry', 'Confused',
#        'Angry', 'Confused', 'Happy', 'Angry', 'Happy', 'Victorious',
#        'Shocked', 'Victorious', 'Angry', 'Sad', 'Shocked', 'Happy', 'Sad',
#        'Sad', 'Sad', 'Shocked', 'Confused', 'Shocked', 'Angry',
#        'Confused', 'Shocked', 'Shocked', 'Shocked', 'Sad', 'Happy',
#        'Victorious', 'Victorious', 'Angry', 'Angry', 'Shocked',
#        'Victorious', 'Angry', 'Happy', 'Shocked', 'Sad', 'Angry',
#        'Victorious', 'Sad', 'Angry', 'Shocked', 'Confused', 'Victorious',
#        'Confused', 'Shocked', 'Happy', 'Sad', 'Angry', 'Confused',
#        'Angry', 'Happy', 'Shocked', 'Shocked', 'Confused', 'Happy',
#        'Shocked', 'Shocked', 'Sad', 'Victorious', 'Confused', 'Confused',
#        'Angry', 'Angry', 'Shocked', 'Sad', 'Angry', 'Shocked', 'Shocked',
#        'Happy', 'Sad', 'Shocked', 'Shocked', 'Confused', 'Angry',
#        'Confused', 'Shocked', 'Confused', 'Sad', 'Sad', 'Happy', 'Happy',
#        'Sad', 'Confused', 'Angry', 'Angry', 'Happy', 'Angry', 'Shocked',
#        'Sad', 'Shocked', 'Angry', 'Confused', 'Happy', 'Confused',
#        'Happy', 'Sad', 'Shocked', 'Shocked', 'Victorious', 'Sad',
#        'Shocked', 'Shocked', 'Happy', 'Sad'], dtype=object)

# %% [markdown]
# # 3.3 - Evaluate and Serialize Model

# %%
from sklearn.metrics import accuracy_score #Accuracy Metrics
import pickle #Using pickle to save our models down to the disks

# %%
for algo, model in fit_models.items():
    yhat = model.predict(X_test)
    print(algo, accuracy_score(y_test, yhat))
# Out:
# lr 1.0
# rc 1.0
# rf 0.9955555555555555
# gb 0.9955555555555555

# %%
fit_models['rf'].predict(X_test)
# Out:
# array(['Happy', 'Sad', 'Sad', 'Angry', 'Confused', 'Victorious', 'Happy',
#        'Angry', 'Sad', 'Confused', 'Shocked', 'Victorious', 'Shocked',
#        'Shocked', 'Angry', 'Shocked', 'Victorious', 'Shocked',
#        'Victorious', 'Victorious', 'Confused', 'Angry', 'Happy', 'Happy',
#        'Shocked', 'Shocked', 'Shocked', 'Shocked', 'Angry', 'Angry',
#        'Angry', 'Happy', 'Shocked', 'Victorious', 'Happy', 'Happy',
#        'Victorious', 'Confused', 'Happy', 'Happy', 'Shocked', 'Confused',
#        'Shocked', 'Happy', 'Confused', 'Happy', 'Confused', 'Happy',
#        'Happy', 'Confused', 'Sad', 'Sad', 'Sad', 'Sad', 'Confused',
#        'Happy', 'Angry', 'Happy', 'Angry', 'Confused', 'Confused',
#        'Shocked', 'Shocked', 'Sad', 'Confused', 'Shocked', 'Victorious',
#        'Confused', 'Confused', 'Shocked', 'Sad', 'Sad', 'Confused',
#        'Confused', 'Confused', 'Angry', 'Victorious', 'Confused',
#        'Confused', 'Angry', 'Confused', 'Victorious', 'Happy', 'Angry',
#        'Sad', 'Sad', 'Happy', 'Confused', 'Sad', 'Confused', 'Confused',
#        'Sad', 'Shocked', 'Shocked', 'Happy', 'Shocked', 'Angry', 'Angry',
#        'Confused', 'Confused', 'Shocked', 'Victorious', 'Victorious',
#        'Victorious', 'Confused', 'Shocked', 'Happy', 'Confused',
#        'Shocked', 'Shocked', 'Shocked', 'Happy', 'Victorious',
#        'Victorious', 'Angry', 'Happy', 'Shocked', 'Victorious', 'Angry',
#        'Angry', 'Victorious', 'Happy', 'Confused', 'Shocked', 'Confused',
#        'Shocked', 'Sad', 'Sad', 'Victorious', 'Happy', 'Confused',
#        'Victorious', 'Confused', 'Angry', 'Shocked', 'Confused',
#        'Confused', 'Confused', 'Confused', 'Confused', 'Victorious',
#        'Angry', 'Shocked', 'Confused', 'Angry', 'Happy', 'Angry', 'Happy',
#        'Shocked', 'Happy', 'Happy', 'Victorious', 'Shocked', 'Shocked',
#        'Shocked', 'Sad', 'Happy', 'Confused', 'Angry', 'Sad', 'Confused',
#        'Angry', 'Victorious', 'Angry', 'Happy', 'Sad', 'Sad', 'Happy',
#        'Happy', 'Sad', 'Happy', 'Shocked', 'Angry', 'Happy', 'Confused',
#        'Victorious', 'Happy', 'Victorious', 'Confused', 'Confused',
#        'Happy', 'Angry', 'Shocked', 'Confused', 'Victorious', 'Sad',
#        'Victorious', 'Sad', 'Shocked', 'Shocked', 'Shocked', 'Shocked',
#        'Happy', 'Sad', 'Angry', 'Happy', 'Shocked', 'Victorious',
#        'Confused', 'Confused', 'Angry', 'Shocked', 'Sad', 'Angry',
#        'Victorious', 'Sad', 'Sad', 'Sad', 'Confused', 'Angry', 'Angry',
#        'Sad', 'Confused', 'Sad', 'Sad', 'Happy', 'Shocked', 'Angry',
#        'Angry', 'Happy', 'Confused', 'Shocked', 'Sad', 'Sad', 'Sad',
#        'Shocked', 'Confused', 'Happy', 'Confused', 'Happy', 'Shocked',
#        'Happy', 'Happy', 'Shocked', 'Victorious', 'Shocked', 'Angry',
#        'Sad', 'Victorious', 'Sad', 'Sad', 'Confused', 'Shocked', 'Happy',
#        'Sad', 'Shocked', 'Confused', 'Confused', 'Shocked', 'Confused',
#        'Angry', 'Happy', 'Victorious', 'Victorious', 'Confused', 'Sad',
#        'Happy', 'Sad', 'Sad', 'Shocked', 'Shocked', 'Confused',
#        'Confused', 'Shocked', 'Shocked', 'Angry', 'Happy', 'Confused',
#        'Confused', 'Confused', 'Shocked', 'Shocked', 'Happy',
#        'Victorious', 'Victorious', 'Victorious', 'Happy', 'Sad', 'Sad',
#        'Victorious', 'Shocked', 'Sad', 'Angry', 'Angry', 'Angry',
#        'Shocked', 'Angry', 'Angry', 'Shocked', 'Confused', 'Angry',
#        'Happy', 'Shocked', 'Happy', 'Sad', 'Confused', 'Happy', 'Happy',
#        'Happy', 'Angry', 'Victorious', 'Confused', 'Confused', 'Shocked',
#        'Confused', 'Happy', 'Victorious', 'Angry', 'Victorious',
#        'Confused', 'Confused', 'Happy', 'Sad', 'Happy', 'Angry', 'Angry',
#        'Shocked', 'Angry', 'Angry', 'Happy', 'Angry', 'Sad', 'Happy',
#        'Angry', 'Happy', 'Confused', 'Shocked', 'Happy', 'Sad',
#        'Victorious', 'Angry', 'Shocked', 'Happy', 'Confused', 'Happy',
#        'Shocked', 'Happy', 'Confused', 'Angry', 'Happy', 'Angry',
#        'Shocked', 'Victorious', 'Shocked', 'Happy', 'Angry', 'Confused',
#        'Angry', 'Confused', 'Happy', 'Angry', 'Happy', 'Victorious',
#        'Shocked', 'Victorious', 'Angry', 'Sad', 'Shocked', 'Happy', 'Sad',
#        'Sad', 'Sad', 'Shocked', 'Confused', 'Shocked', 'Angry',
#        'Confused', 'Shocked', 'Shocked', 'Shocked', 'Sad', 'Happy',
#        'Victorious', 'Victorious', 'Angry', 'Angry', 'Shocked',
#        'Victorious', 'Angry', 'Happy', 'Shocked', 'Sad', 'Angry',
#        'Victorious', 'Sad', 'Angry', 'Shocked', 'Confused', 'Victorious',
#        'Confused', 'Shocked', 'Happy', 'Sad', 'Angry', 'Confused',
#        'Angry', 'Happy', 'Shocked', 'Shocked', 'Confused', 'Happy',
#        'Shocked', 'Shocked', 'Sad', 'Victorious', 'Confused', 'Confused',
#        'Angry', 'Angry', 'Shocked', 'Victorious', 'Angry', 'Shocked',
#        'Shocked', 'Happy', 'Sad', 'Shocked', 'Shocked', 'Confused',
#        'Angry', 'Confused', 'Shocked', 'Confused', 'Sad', 'Sad', 'Happy',
#        'Happy', 'Sad', 'Confused', 'Angry', 'Angry', 'Happy', 'Angry',
#        'Shocked', 'Sad', 'Shocked', 'Angry', 'Confused', 'Happy',
#        'Confused', 'Happy', 'Sad', 'Shocked', 'Shocked', 'Victorious',
#        'Sad', 'Shocked', 'Shocked', 'Happy', 'Sad'], dtype=object)

# %%
y_test
# Out:
# 78         Happy
# 366          Sad
# 351          Sad
# 1370       Angry
# 564     Confused
#           ...
# 301          Sad
# 985      Shocked
# 1080     Shocked
# 83         Happy
# 456          Sad
# Name: class, Length: 450, dtype: object

# %%
#Serializing the model through a pickle file
with open('Body_language.pkl', 'wb') as f: #used 'wb' because I was writing up my binary file here
    pickle.dump(fit_models['rf'], f)

# %% [markdown]
# # 4. Make Detections with Model

# %%
with open('Body_language.pkl', 'rb') as f: #using 'rb' because I want to read the binary file here
    model = pickle.load(f) #deserialize a sequence of bytes into an object.

# %%
model
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('randomforestclassifier', RandomForestClassifier())])

# %%
video_path = '/Users/hanouf/Downloads/conclude.mov'

# Open the video file
cap = cv2.VideoCapture(video_path)


with mp_holistic.Holistic(min_detection_confidence=0.5, min_tracking_confidence=0.5) as holistic:

    while cap.isOpened():
        ret, frame = cap.read()

        #Recoloring the Feed
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False
        
        #Making Detections
        results = holistic.process(image)

        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        #1. Drawing face landmarks
        mp_drawing.draw_landmarks(image, results.face_landmarks, mp_holistic.FACEMESH_TESSELATION,
                                  mp_drawing.DrawingSpec(color=(80,110,10), thickness=1, circle_radius=1),
                                  mp_drawing.DrawingSpec(color=(80,256,121), thickness=1, circle_radius=1)
                                  )

        #2. Right Hand
        mp_drawing.draw_landmarks(image, results.right_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(80,22,10), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(80,44,121), thickness=2, circle_radius=2)
                                  )
        #3. Left Hand
        mp_drawing.draw_landmarks(image, results.left_hand_landmarks, mp_holistic.HAND_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(121,22,76), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(121,44,250), thickness=2, circle_radius=2)
                                  )
        #4. Pose Detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_holistic.POSE_CONNECTIONS,
                                  mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=4),
                                  mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2)
                                  )
        
        #Export Coordinates
        try:
            #Extracting Pose Landmarks
            pose = results.pose_landmarks.landmark
            pose_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in pose]).flatten())

            #Extracting Face Landmarks
            face = results.face_landmarks.landmark
            face_row = list(np.array([[landmark.x, landmark.y, landmark.z, landmark.visibility] for landmark in face]).flatten())

            #Row Concatenation
            row = pose_row+face_row

            #Appending the class name
            #row.insert(0, class_name)

        
            #Exporting to CSV
            #with open('coordinates1.csv', mode='a', newline='') as f:
                #csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
                #csv_writer.writerow(row)

            #Make Detections
            X = pd.DataFrame([row])
            Body_language_class = model.predict(X)[0]
            Body_language_prob = model.predict_proba(X)[0] #predicting the probability of the class
            print(Body_language_class, Body_language_prob)

            #Make Detections
            X = pd.DataFrame([row])
            Body_language_class = model.predict(X)[0]
            Body_language_prob = model.predict_proba(X)[0]
            print(Body_language_class, Body_language_prob)

            #Grabbing the coordinates
            coordinates = tuple(np.multiply(
                                np.array(
                                    (results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x,
                                    results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)
                                    ), [640,480]).astype(int))

            #Positioning
            cv2.rectangle(image,
            (coordinates[0], coordinates[1]+5),
            (coordinates[0]+len(Body_language_class)*20, coordinates[-1]-30),
            (245, 117, 16), -1)
            cv2.putText(image, Body_language_class, coordinates,
            cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

            #Get Status box
            cv2.rectangle(image, (0,0),(250,60), (245, 117, 16), -1)

            # Display Class
            cv2.putText(image, 'CLASS'
                        , (95,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, Body_language_class.split(' ')[0]
                        , (90,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

             # Display Probability
            cv2.putText(image, 'PROB'
                        , (15,12), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 0), 1, cv2.LINE_AA)
            cv2.putText(image, str(round(Body_language_prob[np.argmax(Body_language_prob)],2))
                        , (10,40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2, cv2.LINE_AA)

        except:
            pass

        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows
# Out:
# I0000 00:00:1720427594.023280   11149 gl_context.cc:357] GL version: 2.1 (2.1 INTEL-22.5.11), renderer: Intel(R) Iris(TM) Plus Graphics OpenGL Engine
# W0000 00:00:1720427594.190107   27327 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720427594.211190   27327 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720427594.212350   27329 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720427594.212372   27328 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720427594.213598   27327 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720427594.219465   27327 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720427594.226948   27328 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1720427594.235056   27329 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Victorious [0.   0.03 0.24 0.07 0.01 0.65]
# Victorious [0.   0.03 0.24 0.07 0.01 0.65]
# Victorious [0.   0.02 0.25 0.12 0.01 0.6 ]
# Victorious [0.   0.02 0.25 0.12 0.01 0.6 ]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Victorious [0.   0.02 0.26 0.12 0.01 0.59]
# Victorious [0.   0.02 0.26 0.12 0.01 0.59]
# Victorious [0.   0.02 0.26 0.11 0.01 0.6 ]
# Victorious [0.   0.02 0.26 0.11 0.01 0.6 ]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Victorious [0.   0.02 0.26 0.1  0.01 0.61]
# Victorious [0.   0.02 0.26 0.1  0.01 0.61]
# Victorious [0.   0.02 0.25 0.1  0.01 0.62]
# Victorious [0.   0.02 0.25 0.1  0.01 0.62]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Victorious [0.   0.02 0.23 0.17 0.02 0.56]
# Victorious [0.   0.02 0.23 0.17 0.02 0.56]
# Victorious [0.   0.02 0.23 0.14 0.01 0.6 ]
# Victorious [0.   0.02 0.23 0.14 0.01 0.6 ]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Victorious [0.   0.02 0.24 0.17 0.01 0.56]
# Victorious [0.   0.02 0.24 0.17 0.01 0.56]
# Victorious [0.   0.02 0.24 0.15 0.02 0.57]
# Victorious [0.   0.02 0.24 0.15 0.02 0.57]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Victorious [0.   0.02 0.23 0.15 0.01 0.59]
# Victorious [0.   0.02 0.23 0.15 0.01 0.59]
# Victorious [0.   0.02 0.23 0.15 0.01 0.59]
# Victorious [0.   0.02 0.23 0.15 0.01 0.59]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Victorious [0.   0.02 0.25 0.11 0.01 0.61]
# Victorious [0.   0.02 0.25 0.11 0.01 0.61]
# Victorious [0.   0.02 0.24 0.14 0.02 0.58]
# Victorious [0.   0.02 0.24 0.14 0.02 0.58]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Victorious [0.   0.03 0.26 0.1  0.02 0.59]
# Victorious [0.   0.03 0.26 0.1  0.02 0.59]
# Victorious [0.   0.02 0.26 0.13 0.02 0.57]
# Victorious [0.   0.02 0.26 0.13 0.02 0.57]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Victorious [0.   0.02 0.27 0.11 0.02 0.58]
# Victorious [0.   0.02 0.27 0.11 0.02 0.58]
# Victorious [0.   0.02 0.26 0.1  0.02 0.6 ]
# Victorious [0.   0.02 0.26 0.1  0.02 0.6 ]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Victorious [0.   0.02 0.26 0.1  0.02 0.6 ]
# Victorious [0.   0.02 0.26 0.1  0.02 0.6 ]
# Victorious [0.   0.02 0.22 0.19 0.   0.57]
# Victorious [0.   0.02 0.22 0.19 0.   0.57]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Victorious [0.   0.01 0.16 0.31 0.   0.52]
# Victorious [0.   0.01 0.16 0.31 0.   0.52]
# Victorious [0.   0.01 0.16 0.34 0.01 0.48]
# Victorious [0.   0.01 0.16 0.34 0.01 0.48]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Sad [0.   0.   0.13 0.41 0.07 0.39]
# Sad [0.   0.   0.13 0.41 0.07 0.39]
# Sad [0.   0.   0.09 0.43 0.1  0.38]
# Sad [0.   0.   0.09 0.43 0.1  0.38]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.   0.04 0.76 0.03 0.17]
# Sad [0.   0.   0.04 0.76 0.03 0.17]
# Sad [0.   0.   0.06 0.76 0.01 0.17]
# Sad [0.   0.   0.06 0.76 0.01 0.17]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.   0.07 0.75 0.01 0.17]
# Sad [0.   0.   0.07 0.75 0.01 0.17]
# Sad [0.   0.   0.09 0.73 0.01 0.17]
# Sad [0.   0.   0.09 0.73 0.01 0.17]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.   0.24 0.57 0.01 0.18]
# Sad [0.   0.   0.24 0.57 0.01 0.18]
# Sad [0.   0.   0.36 0.4  0.04 0.2 ]
# Sad [0.   0.   0.36 0.4  0.04 0.2 ]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.   0.36 0.4  0.04 0.2 ]
# Sad [0.   0.   0.36 0.4  0.04 0.2 ]
# Sad [0.   0.   0.35 0.41 0.04 0.2 ]
# Sad [0.   0.   0.35 0.41 0.04 0.2 ]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Sad [0.   0.   0.35 0.4  0.04 0.21]
# Sad [0.   0.   0.35 0.4  0.04 0.21]
# Sad [0.   0.   0.37 0.39 0.04 0.2 ]
# Sad [0.   0.   0.37 0.39 0.04 0.2 ]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Sad [0.   0.   0.37 0.39 0.04 0.2 ]
# Sad [0.   0.   0.37 0.39 0.04 0.2 ]
# Sad [0.   0.   0.37 0.38 0.04 0.21]
# Sad [0.   0.   0.37 0.38 0.04 0.21]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Victorious [0.   0.04 0.38 0.03 0.04 0.51]
# Victorious [0.   0.04 0.38 0.03 0.04 0.51]
# Victorious [0.   0.04 0.37 0.03 0.04 0.52]
# Victorious [0.   0.04 0.37 0.03 0.04 0.52]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Victorious [0.   0.03 0.39 0.03 0.04 0.51]
# Victorious [0.   0.03 0.39 0.03 0.04 0.51]
# Victorious [0.   0.04 0.35 0.04 0.05 0.52]
# Victorious [0.   0.04 0.35 0.04 0.05 0.52]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Victorious [0.   0.04 0.35 0.04 0.05 0.52]
# Victorious [0.   0.04 0.35 0.04 0.05 0.52]
# Victorious [0.   0.04 0.36 0.04 0.04 0.52]
# Victorious [0.   0.04 0.36 0.04 0.04 0.52]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Victorious [0.   0.04 0.32 0.03 0.06 0.55]
# Victorious [0.   0.04 0.32 0.03 0.06 0.55]
# Victorious [0.   0.04 0.36 0.04 0.04 0.52]
# Victorious [0.   0.04 0.36 0.04 0.04 0.52]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Victorious [0.   0.02 0.38 0.04 0.04 0.52]
# Victorious [0.   0.02 0.38 0.04 0.04 0.52]
# Victorious [0.   0.02 0.37 0.04 0.05 0.52]
# Victorious [0.   0.02 0.37 0.04 0.05 0.52]
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/google/protobuf/symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# Victorious [0.   0.02 0.38 0.04 0.04 0.52]
# Victorious [0.   0.02 0.38 0.04 0.04 0.52]
# Victorious [0.   0.02 0.39 0.04 0.04 0.51]
# Victorious [0.   0.02 0.39 0.04 0.04 0.51]
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body Language Decoder.ipynb Cell 76 line 1
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#Y135sZmlsZQ%3D%3D?line=9'>10</a> ret, frame = cap.read()
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#Y135sZmlsZQ%3D%3D?line=11'>12</a> #Recoloring the Feed
# ---> <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#Y135sZmlsZQ%3D%3D?line=12'>13</a> image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#Y135sZmlsZQ%3D%3D?line=13'>14</a> image.flags.writeable = False
#      <a href='vscode-notebook-cell:/Users/hanouf/Downloads/Body-Language-Decoder-main/Code/Body%20Language%20Decoder.ipynb#Y135sZmlsZQ%3D%3D?line=15'>16</a> #Making Detections
#
# error: OpenCV(4.10.0) /Users/runner/work/opencv-python/opencv-python/opencv/modules/imgproc/src/color.cpp:196: error: (-215:Assertion failed) !_src.empty() in function 'cvtColor'

# %%
#Using a numpy array to stack my coordinates for my left ear

tuple(np.multiply(np.array((results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].x,
results.pose_landmarks.landmark[mp_holistic.PoseLandmark.LEFT_EAR].y)), [640, 480]).astype(int))
# Out:
# (353, 339)
